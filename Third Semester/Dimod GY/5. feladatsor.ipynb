# %%
# Írjon függvényt, amely eldönti, hogy a paramétere felbonthatatlan-e.
def Is_Irreducible(a):
# Out:
# 2

# %%
gcd(21, 35)
# Out:
# 7

# %%
#Írjon függvényt a páros Goldbach-sejtés bemutatására. 
#A páros Goldbach-sejtés szerint minden 2-nél nagyobb páros szám felírható két prímszám összegeként.'
#'Ha a függvény argumentuma nem megfelelő, a függvény dobjon ValueError kivételt.'
def Even_Goldbach(n):
    if  n % 2 == 1:
        raise ValueError
    else:
        for p in prime_range(n):
            q = n - p
            if is_prime(q):
                return q
    
#6 = 1 + 5
#8 = 5 + 3
#10= 7 + 3
try:
    Even_Goldbach(1)
except ValueError:
    print("Nem jo bemenet")
# Out:
# Nem jo bemenet

# %%
#Olvasson be a billentyűzetről egy x egész számot. Írjon programot, amely kiírja az összes barátságos szám(párt) x alatt. 
# Futtassa programját x = 100 értékkel.'
x = input("Enter an int: ")
print(type(x))
print(2*int(x))
# Out:
# Enter an int: 5
# <class 'str'>
# 10

# %%
prime_range(10)
# Out:
# [2, 3, 5, 7]

# %%
reset('x')
p1 = plot(x/log(x), (2, 1000) ,scale='semilogy') # fill = lambda
p2 = plot(lambda  x: prime_pi(x), 2, 1000, color = 'red')
p1 + p2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
euler_phi(24)
# Out:
# 8

# %%
p = plot(lambda x: euler_phi(int(x)), 2, 100, rgbcolor=(0, 0.5, 0))
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = points([(k, euler_phi(k)) for k in range(2,100)])
p
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
gcd(2021, 6) # ellenpelda (18, 4) = 2 , 18% 4 = 2
# Out:
# 1

# %%
xgcd(6, 5)
# Out:
# (1, 1, -1)

# %%
mod(8, 5)
# Out:
# 3

# %%
8 % 5
# Out:
# 3
